# %% [markdown]
# # Movimiento Oscilatorio Armonico

# %% [markdown]
# ## Ecuación diferencial de un MAS

# %% [markdown]
# Esta ecuación nos describe la aceleración de un movimiento armonico simple en base a la posición y se cumple para cualquier sistema.

# %% [markdown]
# $$\large a= \frac{d^2 x(t)}{dt^2} = -C\cdot x (t) $$

# %% [markdown]
# La solución para la ecuacion general de un MAS es:

# %% [markdown]
# ![MOA1.JPG](attachment:MOA1.JPG)

# %% [markdown]
# #### Significado fisico de las constantes:

# %% [markdown]
# **Amplitud**: es el máximo desplazamiento de la partícula o cuerpo con respecto a su posición de equilibrio. Puede ser lineal o angular.

# %% [markdown]
# **Pulsación o frecuencia angular**: Permite escribir el argumento de la función armónica en términos de ángulos en radianes, está relacionada con el período $T = \frac{2\pi}{\omega}$ de la oscilación. Depende del sistema físico oscilante.

# %% [markdown]
# **Fase inicial o constante de fase**: Ángulo en radianes que permite adecuar las ecuaciones horarias del MAS a las condiciones iniciales del problema.

# %% [markdown]
# **Periodo** : Es el tiempo que tarda la masa en efectuar una oscilación completa.

# %% [markdown]
# **Frecuencia**: Es el numero de oscilaciones que se realiza en un segundo. $f=\frac{1}{T}$ y se mide en $\frac{1}{s} = Hz$

# %% [markdown]
# ### Notas:

# %% [markdown]
# La velocidad es máxima o mínima en el punto de equilibrio y es $0$ enm los extremos de la oscilación.

# %% [markdown]
# La aceleración es cero en el punto de equilibrio y es maxima o minima en los extremos de la oscilación.

# %% [markdown]
# ### Sistema masa-resorte

# %% [markdown]
# $$\begin{matrix}
# a(t)=-\omega \cdot x(t)\\
# F(t) = -k \cdot x (t)\\
# a(t)m = -k \cdot x(t)\\
# a(t) = -\frac{k}{m} \cdot x(t)\\
# \omega^2 = \frac{k}{m} \Rightarrow T = \frac{2\pi}{\omega} = 2\pi \cdot \sqrt{\frac{m}{k}}
# \end{matrix}$$

# %% [markdown]
# ### Sistema pendulo ideal

# %% [markdown]
# $$
# \omega^2 = \frac{g}{L} \Rightarrow T = \frac{2\pi}{\omega} = 2\pi \cdot \sqrt{\frac{L}{g}}
# $$

# %% [markdown]
# ### Sistema péndulo fisico

# %% [markdown]
# $$
# \omega^2 = \frac{mgd}{I^{eje}_{cr}} \Rightarrow T = \frac{2\pi}{\omega} = 2\pi \cdot \sqrt{\frac{I^{eje}_{cr}}{mgd}}
# $$

# %% [markdown]
# ## Energía en un MAS

# %% [markdown]
# En los MAS (casos ideales sin roce) no hay trabajo de fuerzas no conservativas por lo que se conserva la energía mecánica de la particula o rígido.

# %% [markdown]
# ![MOA2.JPG](attachment:MOA2.JPG)

# %% [markdown]
# ![MOA3.JPG](attachment:MOA3.JPG)
