# %% [markdown]
# # Cuerpo rígido

# %% [markdown]
# ## Cinematica

# %% [markdown]
# ### Rotación pura

# %% [markdown]
# Velocidad de un punto.

# %% [markdown]
# $\bar{v}_a =\bar{\omega}\times \bar{r} $

# %% [markdown]
# Donde $\bar{\omega}$ es un vector colineal con el eje de rotación y el modulo está dado por el valor absoluto de $\omega$ y cuyo sentido esta dado por la regla del tirabuzón.

# %% [markdown]
# ## Rototraslación

# %% [markdown]
# Velocidad de un punto:

# %% [markdown]
# $\bar{v}_a =\bar{\omega}\times \bar{r}+\bar{v}_{eje}  $

# %% [markdown]
# Notar que $\bar{v}_{eje} = v_{traslación}$

# %% [markdown]
# ### Movimientos "planos"

# %% [markdown]
# $$\begin{matrix}
# \bar{\omega} \perp \bar{v}_{eje}\\
# \bar{v_a} = \bar{\omega}\times \bar{r}_{a,eje}+\bar{v}_{eje}\\
# \bar{v_a} = \bar{v}_{a,rotacion} + \bar{v}_{a,traslacion}
# \end{matrix}$$

# %% [markdown]
# Siempre es posible encontrar un determinado punto $C$ tal que su velocidad de traslación es el opuesto de su velocidad de rotación, es decir ese punto está instantaneamente quieto.

# %% [markdown]
# Por como se calculan las velocidades angulares siempre hay una **recta** instantaneamente quieta dentro o fuera del rigido llamado $EIR$ eje instantaneo de rotación.

# %% [markdown]
# Todo movimiento rotrotraslatorio se puede llevar a una rotación pura con tal de referenciar el movimiento al $EIR$

# %% [markdown]
# $$\bar{v_a} = \bar{\omega}\times \bar{r}_{a,EIR}$$

# %% [markdown]
# ### Rodadura

# %% [markdown]
# ![CuerpoRigido1.JPG](attachment:CuerpoRigido1.JPG)

# %% [markdown]
# ![CuerpoRigido2.JPG](attachment:CuerpoRigido2.JPG)

# %% [markdown]
# ![CuerpoRigido3.JPG](attachment:CuerpoRigido3.JPG)

# %% [markdown]
# ## Dinamica

# %% [markdown]
# ### Dinamica de la traslación

# %% [markdown]
# $$\large\sum \bar{F}_{ext} = M_{total} \cdot \bar{a}_{cm}$$

# %% [markdown]
# ### Dinamica de la rotación

# %% [markdown]
# ![CuerpoRigido4.JPG](attachment:CuerpoRigido4.JPG)

# %% [markdown]
# $$\large\sum \bar{M}_{F_{ext}}^o = I_{cr}^{eje} \cdot \bar{\gamma}$$

# %% [markdown]
# Donde $I$ es el momento de inercia de un cuerpo respecto a un eje y $\bar{\gamma}$ es la aceleración angular.

# %% [markdown]
# $$I_{cr}^{eje} = \sum m_i \cdot d_i^2$$

# %% [markdown]
# ![CuerpoRigido5.JPG](attachment:CuerpoRigido5.JPG)

# %% [markdown]
# Además se puede calcular el momento de inercia respecto a otro eje paralelo, a partir del momento de inercia baricéntrico.

# %% [markdown]
# ![CuerpoRigido6.JPG](attachment:CuerpoRigido6.JPG)

# %% [markdown]
# #### Radio de giro

# %% [markdown]
# Es la distancia $k$ desde el eje de rotación a al cual debería ubicarse toda la masa del cuerpo rígido para que su momento de inercia respecto al eje sea igual al del cuerpo rígido original.

# %% [markdown]
# ![CuerpoRigido7.JPG](attachment:CuerpoRigido7.JPG)

# %% [markdown]
# ### Ecuaciones de dinamica para movimientos planos

# %% [markdown]
# ![CuerpoRigido8.JPG](attachment:CuerpoRigido8.JPG)

# %% [markdown]
# ### Cuplas

# %% [markdown]
# Es un par de fuerzas de igual modulo y direccion y sentidos opuestos separadas uan distancia $d$

# %% [markdown]
# ![CuerpoRigido9.JPG](attachment:CuerpoRigido9.JPG)

# %% [markdown]
# ## Teoremas para cuerpo rígido

# %% [markdown]
# ### Impulso y cantidad de movimiento

# %% [markdown]
# $$\large\sum \bar{J}_{F_{ext,\Delta t}} = \Delta \bar{p}_{cm,\Delta t}$$

# %% [markdown]
# Recordemos que $\bar{p}_{cm} = M\cdot \bar{v}_{cm} $

# %% [markdown]
# y además $\bar{J}_F = \bar {F} \cdot \Delta t$

# %% [markdown]
# ### Trabajo y energía

# %% [markdown]
# $$\large\sum W_{F_{ext,A-B}} = \Delta E_{C_{CR,A-B}}$$

# %% [markdown]
# $$\large\sum W_{FNC_{ext,A-B}} = \Delta E_{M_{CR,A-B}}$$

# %% [markdown]
# Ecuaciones de energia para cuerpo rígido:

# %% [markdown]
# $$E_{C_{traslacion}} = \frac{1}{2} m \cdot v_{cm}^2$$

# %% [markdown]
# $$E_{C_{rotacion}} = \frac{1}{2} I^{cm}_{cr} \cdot \omega^2$$

# %% [markdown]
# $$E_C = E_{C_{traslacion}} + E_{C_{rotacion}}$$

# %% [markdown]
# Ecuaciones de trabajo para cuerpo rígido:

# %% [markdown]
# #### Traslación

# %% [markdown]
# $$W_F = \bar{F} \cdot \Delta \bar{r}_{cm}= |\bar{F}||\Delta\bar{r}|\cos \alpha$$

# %% [markdown]
# #### Rotacion pura alrededor de un eje baricentrico

# %% [markdown]
# $$W_F = \bar{M}_{F}^{cm} \cdot \Delta \bar{\theta}= |\bar{M}_{F}^{cm}||\Delta \bar{\theta}|\cos \alpha$$

# %% [markdown]
# #### Rototraslacion

# %% [markdown]
# $$W_{F_{neto}} = W_{F_{traslacion}} + W_{F_{rotacion}}$$

# %% [markdown]
# ### Impulso de momentos y variacion del momento cinetico

# %% [markdown]
# $$\large\sum \bar{J}_{\bar{M}_{\bar{F_{ext}}}^o\Delta t} = \Delta \bar{L}_{{cr}\Delta t}^o$$

# %% [markdown]
# Ecuaciones de momento cinetico para cuerpo rigido

# %% [markdown]
# Recordemos que $\bar{M}_F^o = \bar{r} \times \bar{F}\hspace{5pt}$ y $\hspace{5pt}\bar{J}_{M_F^o \Delta t} = \bar{M}_F^o \cdot \Delta t$

# %% [markdown]
# #### Traslacion

# %% [markdown]
# $$\bar{L}_{cm}^o = \bar{r}_{cm} \times \bar{p}_{cm}$$

# %% [markdown]
# #### Rotacion pura al rededor de un eje baricentrico

# %% [markdown]
# $$\bar{L}_{cr}^{cm} = I^{bar}_{cr} \cdot \bar{\omega}$$

# %% [markdown]
# #### Rototraslacion

# %% [markdown]
# $$\large\bar{L}_{cr}^{o} = \bar{L}_{cm}^o + \bar{L}_{cr}^{cm} = \bar{r}_{cm} \times \bar{p}_{cm} + I^{bar}_{cr} \cdot \bar{\omega}$$
