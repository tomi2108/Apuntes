# %% [markdown]
# ## Alfabetos

# %% [markdown]
# Un alfabeto es un conjunto finito no vacío, sin elementos que se obtengan por yuxtaposición, es decir que ningún simbolo se pueda formar colocando uno a continuación de otro. Se los denota con : $\Sigma$ o $V$

# %% [markdown]
# **Palabra**: secuencia finita de letras formada por caracteres de un alfabeto.
#
# **Palabra Nula**: está formada por 0 letras, se denota $\lambda$ o $\varepsilon$
#
# **Longitud**: cantidad de letras que forman una palabra.

# %% [markdown]
# ### Clausura de Kleene de un alfabeto

# %% [markdown]
# Se define: $$V^* = V^0 \cup V^0 \cup V^1 \cup V^2 \cdots V^n \cup  \cdots$$

# %% [markdown]
# $V^i$: conjunto de palabras de longitud $i$ formadas con las letras del alfabeto $V$

# %% [markdown]
# $V^*$ es el conjunto de todas las palabra de cualquier longitud, que se pueden escribir con letras del alfabeto $V$

# %% [markdown]
# ### Concatenación de palabras

# %% [markdown]
# Sea $w_1 \in V^*$ , $w_2 \in V^*$ y $w_3 = w_1 \cdot w_2$ entonces $w_3$ está formada por las letras de $w_1$ a continuación por las letras de $w_2$.

# %% [markdown]
# $$long(w_1 \cdot w_2) = long(w_1) + long( w_2)$$

# %% [markdown]
# Además: $$(w_1 \cdot w_2)\cdot w_3 = w_1 \cdot (w_2 \cdot w_3)$$

# %% [markdown]
# $(V^*;\cdot)$ es un semigrupo con neutro $\lambda$ y se lo llama **Semigrupo libre** generado por $V$

# %% [markdown]
# ###  Inversión, reflexión o transposición

# %% [markdown]
# Dada $w \in V^*$, si $w = x_1x_2x_3\cdots x_{n-1}x_n$ se define: $$w^R =x_nx_{n-1}\cdots x_3x_2x_1 $$

# %% [markdown]
# #### Propiedades de la reflexión

# %% [markdown]
# 1. $(w^R)^R = w$
# 2. $\lambda^R = \lambda$
# 3. $(w \cdot y)^R = y^R \cdot w^R $
# 4. $long(w^R) = long(w)$

# %% [markdown]
# ### Palíndrome

# %% [markdown]
# Sea $w \in V^*$, $w$ es palindrome $\Leftrightarrow w=w^R$

# %% [markdown]
# ### Potencia de una palabra

# %% [markdown]
# Sea $w \in V^*$, con $n \in \mathbb{N}_0$ se define: $$\left\{\begin{matrix}
# w^0 = \lambda\\
# w^1 = w\\
# w^n = w\cdot w^{n-1}
# \end{matrix}\right.$$

# %% [markdown]
# **Propiedad:** $long(w^n) = n\cdot long(w)$

# %% [markdown]
# # Lenguaje

# %% [markdown]
# Sea $L$ un conjunto y $V$ un alfabeto.
#
# Diremos que $L$ es un lenguaje $\Leftrightarrow L \subseteq V^*$
#
# O sea un lenguajes es todo subconjunto de $V^*$

# %% [markdown]
# ### Observaciones

# %% [markdown]
# 1. Los elementos de $L$ son palabras.
# 2. Los lenguajes pueden ser finitos o infinitos.
# 3. Como $L \subseteq V^*$ entocnes $L \in P(V^*)$
# 4. Se pueden aplicar todas las propiedades y operaciones de conjuntos

# %% [markdown]
# Algunos lenguajes especiales son $L= \{\lambda \} = \Lambda$ se llama **Lenguaje nulo** y $L= \emptyset$ se llama **Lenguaje vacío**

# %% [markdown]
# ## Operaciones con lenguajes

# %% [markdown]
# ### Concatenacion de lenguajes

# %% [markdown]
# $L = L_1 \cdot L_2 = \{x\cdot y \;\;/\;\; x\in L_1 \;\;\wedge \;\; y \in L_2  \} $

# %% [markdown]
# Son todas las palabras que se pueden formar concatenando cualquier palabra de $L_1$ con cualquier palabras de $L_2$

# %% [markdown]
# #### Propiedades

# %% [markdown]
# 1. $|L_1 \cdot L_2| \leq |L_1|\cdot |L_2|$
#
#
# 2. $(P(V^*);\cdot )$ semigrupo con neutro $\Lambda$
#
#
# 3. $L_1 \cdot L_2 \neq L_2 \cdot L_1$
#
#
# 4. $L = \emptyset$ es elemento **absorbente** de la concatenación
#
#
# 5. Si $L_1 \subset L_2$ y $L_3 \subset L_4$ entonces $L_1 \cdot L_3 \subset L_2 \cdot L_4$

# %% [markdown]
# ### Lenguaje inverso, reflejo o traspuesto

# %% [markdown]
# $$L^R = \{w^R \;\;/ \;\; w \in L\}$$

# %% [markdown]
# Es decir $L^R$ tiene todas las palabras de $L$ pero reflejadas.

# %% [markdown]
# ### Potencia de un lenguaje

# %% [markdown]
# Sea $L$ un lenguaje, con $n \in \mathbb{N}_0$ se define:

# %% [markdown]
# $$\left\{\begin{matrix}
# L^0 = \Lambda\\
# L^1 = L\\
# L^n = L\cdot L^{n-1}
# \end{matrix}\right.$$

# %% [markdown]
# ### Clausura de Kleene de un lenguaje

# %% [markdown]
# $$L^* = \bigcup_{n=0}^{\infty } L ^n = L^0\cup L^1 \cup L^2 \cdots \cup L^n\cup \cdots$$

# %% [markdown]
# O sea, en la clausura de un lenguaje están todas las palabras que se obtienen concatenando las de $L$ cualquier cantidad de veces.

# %% [markdown]
# **Observaciones**:
#
# 1. $\Lambda^* = \Lambda$
#
# 2. $\emptyset^* = \Lambda$
#
# 3. $\forall L: \lambda \in L^*$

# %% [markdown]
# ### Clausura positiva de un lenguaje

# %% [markdown]
# $$L^+ = \bigcup_{n=1}^{\infty } L ^n =  L^1 \cup L^2 \cdots \cup L^n\cup \cdots$$

# %% [markdown]
# **Observaciones**:
#
# 1. $\Lambda^+ = \Lambda$
#
# 2. $\emptyset^+ = \emptyset$

# %% [markdown]
# ### Complemento de un lenguaje

# %% [markdown]
# $$\bar{L} = V^* - L$$

# %% [markdown]
# #### Ej:

# %% [markdown]
# Sea $V= \{a,b\}$

# %% [markdown]
# $L_1 = \{w \in V^* \;\;/\;\; w \;\;\text{comienza con} \;\;a  \}$
#
# Entonces el complemento de $L_1$ es:
#
# $\bar{L}_1 = \{w \in V^* \;\;/\;\; w \;\;\text{ no comienza con} \;\;a  \}$

# %% [markdown]
# # Gramaticas

# %% [markdown]
# Una gramatica es una cuaterna $G = (V_n;V_t;P;S)$ siendo:
#
# $V_n$: Vocabulario o alfabeto de **no terminales**
#
#
# $V_t$: Vocabulario o alfabeto de **terminales**
#
#
# $P$: Producciones
#
#
# $S$: simbolo variable incial

# %% [markdown]
# ***Requisitos***

# %% [markdown]
# 1. $V_n$ y $V_t$ son finitos.
#
#
# 2. $V_n \cap V_t = \emptyset$
#
#
# 3. $P$ es finito y $P \subset (V^+ - V_t^*)$ siendo $V = V_n \cup V_t $
#
#
# 4. $S$ pertenece a $V_n$

# %% [markdown]
# **Observaciones**
#
# 1) La gramática va a generar palabras formadas por las letras del alfabeto de **terminales** $V_t$. El otro alfabeto, $V_n$, contiene las variables o **no terminales** que se usan para ir formando las palabras.
#
#
# 2) Las producciones son reglas gramaticales. En vez de escribirlas en forma de par ordenado $( a ; b )$ , se escriben como $a → b$ y se lee "$a$ produce $b$". Ello significa que la parte “$a$” puede reemplazarse por “$b$”. Por ello, en la primera parte no puede haber terminales solas ni $\lambda$. Siempre al menos debe haber una variable para hacer el reemplazo.
#
#
# 3) El lenguaje generado por la gramática $G$ se llama $L(G)$.
#
#
# 4) Puede haber varias gramáticas que generen un mismo lenguaje, pero el lenguaje que genera una gramática es único.

# %% [markdown]
# ### Ej:

# %% [markdown]
# Sea la gramatica $G = \{\left(\{S,X,Y\},\{a,b,c\},P,S   \right)\}$ con el conjunto $P$ : $$\begin{matrix}
# S\rightarrow aSb + aX\\
# X\rightarrow cX + bY\\
# Y\rightarrow a
# \end{matrix}$$

# %% [markdown]
# Para hallar palabras de $L(G)$ debemos ir aplicando sucesivas veces las producciones hasta lograr palabras, comenzando por alguna de las producciones que comienzan con el símbolo inicial $S$.

# %% [markdown]
# $$$$

# %% [markdown]
# $$$$

# %% [markdown]
# $$$$

# %% [markdown]
# $$$$

# %% [markdown]
# $$$$

# %% [markdown]
# ## Árbol de derivación

# %% [markdown]
# Es un arbol cuya raíz es el simbolo inicial, y cada vértice tiene tantos hijos como producciones diferentes existan que parten de dicho vértice. Es decir: Si $A\rightarrow B$, entonces $A$ es padre de B. Si $A \rightarrow B + C$, entonces $A$ tiene dos hijos: $B$ y $C$.
# En este tipo de arboles, las hojas son las palabras del lenguaje, y cada rama nos da la derivación de dicha palabra.

# %% [markdown]
# Construiremos el arbol de derivación de la gramatica de arriba.

# %% [markdown]
# Comenzamos con las producciones de $S$

# %% [markdown]
# ![Gramaticas1.JPG](attachment:Gramaticas1.JPG)

# %% [markdown]
# Ahora consideremos las producciones de $X$, con lo que podemos agregar:

# %% [markdown]
# ![Gramaticas2.JPG](attachment:Gramaticas2.JPG)

# %% [markdown]
# Si consideramos ahora la producción de $Y$, ya obtenemos una expresión formada solamente por terminales, es decir ua palabra del lenguaje, la recuadramos:

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Pero debemos continuar con la otra rama, otra vez la variable $X$

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Y seguimos de esta forma ahora con $X$ y con $Y$:

# %% [markdown]
# ![Gramaticas5.JPG](attachment:Gramaticas5.JPG)

# %% [markdown]
# Podemos ver que todo el subárbol derecho del árbol principal genera las palabras de la forma $ac^nba$, con $n\geq 0$ pero aún falta el subárbol izquierdo, es decir el que tiene por raíz. $aSb$

# %% [markdown]
# ![Gramaticas6.JPG](attachment:Gramaticas6.JPG)

# %% [markdown]
# Luego, por cada sub-árbol de mas a la izquierda, lo que agregan es una "a" mas a izquierda y una "b" a derecha simultáneamente. Por lo tanto el lenguaje que genera esta Gramática es:
#
#
# $$L(G) = \{ a^mac^nbab^m \;\;/\;\; n\geq 0 , m\geq 0  \}$$

# %% [markdown]
# Dos gramaticas son **equivalentes** si generan el mismo Lenguaje.

# %% [markdown]
# ### Tipos de Gramáticas

# %% [markdown]
# $$\begin{vmatrix}
# \text{Tipo} &\text{Nombre}  &\text{Producciones} \\
#  0&\text{Irrestricta}  &\text{Cualquier forma} \\
#  1&\text{Sensible al contexto}  &aXb\rightarrow aYb\;\; \text{donde}\;\; a,b,Y\in V^*, X \in V_n  \\
#  2& \text{Independiente del contexto} &X \rightarrow Y \;\;\text{donde}\;\; X \in V_n \\
#  3& \text{Regular} & X\rightarrow Y \;\;\text{donde}\;\; X \in V_n, Y\;\;\text{puede ser}\;\; Vt,tV,t,\lambda
# \end{vmatrix}$$

# %% [markdown]
# Se dice que un Lenguaje $L$ es regular si existe una gramatica regular que lo genera.

# %% [markdown]
# #### Ej:

# %% [markdown]
# Sea $G= \{(A,B,C),\{0,1,2\},P,A \} $

# %% [markdown]
# Tipo $0$:
# $$P = \left\{\begin{matrix}
# A \rightarrow A2 + 11B\\
# 1B \rightarrow 01+0C21\\
# C22 \rightarrow 2 + 2C
# \end{matrix}\right.$$

# %% [markdown]
# Tipo $1$:
# $$P = \left\{\begin{matrix}
# A \rightarrow 0BC\\
# 0B \rightarrow 011+0B1\\
# 1C \rightarrow 12 + 12C
# \end{matrix}\right.$$

# %% [markdown]
# Tipo $2$:
# $$P = \left\{\begin{matrix}
# A \rightarrow BC\\
# B \rightarrow 01+0B1\\
# C \rightarrow 2 + 2C
# \end{matrix}\right.$$

# %% [markdown]
# Tipo $3$:
# $$P = \left\{\begin{matrix}
# A \rightarrow 1B + 0A\\
# B \rightarrow 0 + 0C\\
# C \rightarrow 2 + 2C
# \end{matrix}\right.$$

# %% [markdown]
# ## Expresiones regulares

# %% [markdown]
# Una $E.R.$ es una secuencia de elementos que verfica: $$\begin{matrix}
# \lambda\; \text{es}\; ER \\
# a \in V \Rightarrow a\;\text{es}\; ER\\
# \text{Si}\;X,Y\;\text{son}\;ER \Rightarrow X\cdot Y \;\text{es}\;ER\\
# \text{Si}\;X,Y\;\text{son}\;ER \Rightarrow X + Y \;\text{es}\;ER\\
# \text{Si}\;X\;\text{es}\;ER \Rightarrow X^* \;\text{es}\;ER
# \end{matrix}$$

# %% [markdown]
# O sea, las expresiones regulares sólo pueden contener letras del alfabeto, la palabra nula $\lambda$, concatenaciones $(\cdot)$, disyunciones $(+)$ y clausuras de Kleene $(*)$

# %% [markdown]
# **Propiedad**: Para cada Lenguaje regular, existe una expresión regular que lo define.

# %% [markdown]
# ### Ej:

# %% [markdown]
# El lenguaje regular: $L =\{1^n0^m2^{2p+1}(0 \,\vee\, 1 ) \;/\; n\geq 0, m\geq 1, p\geq 0\}$ Se puede indicar con la $ER$: $$1^*00^*(22)^*2(0\,+\, 1)$$

# %% [markdown]
# $$$$

# %% [markdown]
# $$$$

# %% [markdown]
# $$$$

# %% [markdown]
# # Automatas

# %% [markdown]
# Cada lenguaje tiene su propia maquina reconocedora del mismo.

# %% [markdown]
# $$\begin{vmatrix}
# \text{Lenguaje Tipo} & \text{Maquina que lo reconoce}\\
#  0&\text{Maquina de Turing} \\
#  1&\text{Automata linealmente acotado} \\
#  2&\text{Automata de pila (Push Down)} \\
#  3&\text{Automata Finito}
# \end{vmatrix}$$

# %% [markdown]
# En esta asignatura solo estudiaremos los **Automatas Finitos**

# %% [markdown]
# ## Automatas Finitos

# %% [markdown]
# Un automata Finito es una $5$-upla: $(Q,V,\delta,q_0,F)$ donde:
#
#
# $Q$: Conjunto finito de estados.
#
#
# $V$: Vocabulario o alfabeto de entrada.
#
#
# $\delta$: $Q \times V \rightarrow Q$ Función de transición.
#
#
# $q_0$: Estado inicial.
#
#
# $F$: Conjunto de estados finales $F\neq \emptyset$ y $F\subset Q$

# %% [markdown]
# Los Automatas Finitos se pueden representar con **Tablas de transición** o con **Diagramas de transición de estados**.

# %% [markdown]
# Un Automata acepta una palabra si y solo si al ir ingresando letra por letra desde el estado inicial llega a un estado final cuando termina la palabra.

# %% [markdown]
# ### Clasificación de los A.F.

# %% [markdown]
# Los Automatas finitos pueden ser **Deterministicos** (A.F.D) o **No Deterministicos** (A.F.N)

# %% [markdown]
# Un Automata finito es **Deterministico** si no tiene transiciones por $\lambda$ y $\delta$ cumple unicidad.

# %% [markdown]
# $$$$

# %% [markdown]
# ## Metodo para obtener la E.R. a partir del A.F.

# %% [markdown]
# ![Gramaticas7.JPG](attachment:Gramaticas7.JPG)

# %% [markdown]
# Se escribe $p = aq$

# %% [markdown]
# ![Gramaticas8.JPG](attachment:Gramaticas8.JPG)

# %% [markdown]
# Se escribe: $p=aq+br$

# %% [markdown]
# ![Gramaticas9.JPG](attachment:Gramaticas9.JPG)

# %% [markdown]
# Se escribe $p=a^*$

# %% [markdown]
# ![Gramaticas10.JPG](attachment:Gramaticas10.JPG)

# %% [markdown]
# Se escribe: $p= a^*(bq)$

# %% [markdown]
# $$$$

# %% [markdown]
# ![Gramaticas11.JPG](attachment:Gramaticas11.JPG)

# %% [markdown]
# Se escribe $p = \lambda$

# %% [markdown]
# ## Obtencion de la G.R.  a partir del A.F.

# %% [markdown]
# Sea $A=(Q,V,\delta ,q_0,F)$ queremos hallar una Gramatica $G=(V_n,V_t,P,S)$ que genere el mismo lenguaje que es reconocido por el automata.

# %% [markdown]
# Los elementos de la gramatica se obtienen de la siguiente forma:
#
#
# $V_n = Q$ (Los estados pasan a ser las variables)
#
#
# $V_t = V$ (El alfabeto de terminales es el alfabeto de entrada del A.F)
#
#
# $S = q_0$ (El símbolo inicial es el que era estado inicial)
#
#
# Y las producciones $P$ son tales que: $q\rightarrow a \delta(q,a)$ y $q\rightarrow \lambda$ si $q$ es estado final.

# %% [markdown]
# ## Obtencion del A.F. a partir de la G.R.

# %% [markdown]
# Dada $G=(V_n,V_t,P,S)$ queremos hallar un automata $A=(Q,V,\delta ,q_0,F)$ que reconozca el lenguaje generado por esta gramatica.

# %% [markdown]
# Los elementos del automata se obtienen de la siguiente forma:
#
#
# $Q = V_n \cup\{f\} $ (Los estados son las variables más un nuevo estado que se agrega)
#
#
# $V = V_t$ (El alfabeto de entrada es el alfabeto de terminales)
#
#
# $q_0 = S$ (El estado inicial es el que era el símbolo inicial)
#
#
# $F = \{ q\in V_n \;\;/\;\; q \rightarrow \lambda    \}\cup \{f\}$ (Los estados finales son todos los que producían la palabra unla y además el estado que se agrega)
#
#
# Y la función de transición $\delta$ es tal que:
#
# $$\begin{matrix}
# \delta(q,a)=p \;\;\text{si}\;\;q\rightarrow ap\\
# \delta(q,a)=f \;\;\text{si}\;\;q\rightarrow a\\
# \delta(t,a)=\emptyset
# \end{matrix}$$
