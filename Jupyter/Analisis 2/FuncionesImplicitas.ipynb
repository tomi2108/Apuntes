# %% [markdown]
# # Funciones definidas de forma implicita

# %% [markdown]
# ## Teorema de Cauchy-Dini

# %% [markdown]
# ![FuncionesImplicitas1.JPG](attachment:FuncionesImplicitas1.JPG)

# %% [markdown]
# ![FuncionesImplicitas2.JPG](attachment:FuncionesImplicitas2.JPG)

# %% [markdown]
# ![FuncionesImplicitas3.JPG](attachment:FuncionesImplicitas3.JPG)

# %% [markdown]
# ![FuncionesImplicitas4.JPG](attachment:FuncionesImplicitas4.JPG)
