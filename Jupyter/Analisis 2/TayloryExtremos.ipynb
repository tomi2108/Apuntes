# %% [markdown]
# # Taylor y extremos

# %% [markdown]
# ## Cauchy-Dini

# %% [markdown]
# ![TayloryExytremos1.JPG](attachment:TayloryExytremos1.JPG)

# %% [markdown]
# ![TayloryExytremos2.JPG](attachment:TayloryExytremos2.JPG)

# %% [markdown]
# ## Polinomio de Taylor Orden 1

# %% [markdown]
# ![TayloryExytremos3.JPG](attachment:TayloryExytremos3.JPG)

# %% [markdown]
# ## Polinomio de Taylor Orden 2

# %% [markdown]
# ![TayloryExytremos4.JPG](attachment:TayloryExytremos4.JPG)

# %% [markdown]
# # Extremos de Campos Escalares

# %% [markdown]
# ![TayloryExytremos5.JPG](attachment:TayloryExytremos5.JPG)

# %% [markdown]
# ![TayloryExytremos6.JPG](attachment:TayloryExytremos6.JPG)

# %% [markdown]
# ![TayloryExytremos7.JPG](attachment:TayloryExytremos7.JPG)

# %% [markdown]
#  ![TayloryExytremos8.JPG](attachment:TayloryExytremos8.JPG)
