# %% [markdown]
# # Teoremas

# %% [markdown]
# ## Divergencia y rotacional de un campo vectorial

# %% [markdown]
# Sea un campo vectorial $\bar{f}: D \subset \mathbb{R}^3 \rightarrow \mathbb{R}^3 \,\,/\,\, \bar{f}(x,y,z) = \left ( P(x,y,z) , Q(x,y,z) , R(x,y,z) \right )$ con $\bar{f} \in C^1 (D)$

# %% [markdown]
# Se define la divergencia del campo $\bar{f}$ como:

# %% [markdown]
# $$div \bar{f} = \frac{\partial P }{\partial x}+\frac{\partial Q}{\partial y}+\frac{\partial R}{\partial z}$$

# %% [markdown]
# $\hspace{1pt}$

# %% [markdown]
# Es un campo escalar.

# %% [markdown]
# Si recordamos el operador nabla $\nabla = (\frac{\partial }{\partial x},\frac{\partial }{\partial y},\frac{\partial }{\partial z})$

# %% [markdown]
# $$div \bar{f} = \nabla\cdot\bar{f} $$

# %% [markdown]
# Si $\bar{f}$ representa un campo de velocidades de un fluido entonces si $div\bar{f} > 0$ el gas se está expandiendo. Si $div \bar{f} <0 $ el gas se esta comprimiendo. Y si $div \bar{f} = 0 $ el campo vectorial se llama solenoidal.

# %% [markdown]
# El rotor o rotacional del campo vectorial $\bar{f}$ se define:

# %% [markdown]
# $$rot \bar{f} = \left ( \frac{\partial R}{\partial y} -\frac{\partial  Q}{\partial z}, \frac{\partial P}{\partial z} -\frac{\partial  R}{\partial x}, \frac{\partial Q}{\partial x} -\frac{\partial  P}{\partial y} \right )$$

# %% [markdown]
# Si introducimos el operador nabla $\nabla = (\frac{\partial }{\partial x},\frac{\partial }{\partial y},\frac{\partial }{\partial z})$

# %% [markdown]
# $$rot \bar{f} = \nabla \times \bar{f}$$

# %% [markdown]
# Si $rot \bar{f} =  \bar{0}$ el campo se llama irrotacional. Si $ \bar{f}$ representa un campo de velocidades de un fluido entonces  $rot \bar{f} =  \bar{0}$ en un punto $P$ significa fisicamente que el fluido no tiene rotaciones en dicho punto $P$.

# %% [markdown]
# ## Propiedades

# %% [markdown]
# Si $\bar{f} \in C^2$ entonces:  $$div(rot\bar{f}) = 0$$

# %% [markdown]
# $$\nabla \cdot (\nabla \times \bar{f} )= 0$$

# %% [markdown]
# Sea $f : D \subset \mathbb{R}^3 \rightarrow \mathbb{R}$  un campo escalar. Si $f \in C^2 (D)$ entonces el rotor de un gradiente es el vector nulo:

# %% [markdown]
# $$\nabla\times(\nabla f)= \bar{0}$$

# %% [markdown]
# Por ultimo el laplaciano de $f$ se define:

# %% [markdown]
# $$\nabla^2f = \nabla \cdot \nabla f$$

# %% [markdown]
# Si $\nabla^2 f = 0$ el campo escalar es armónico.

# %% [markdown]
# ## Teorema de la divergencia

# %% [markdown]
# Sea $H \subset \mathbb{R}^3 $ un macizo con superficie frontera $S$, orientada con el campo de normales hacia el exterior. Si $\bar{f}: D \subset \mathbb{R}^3 \rightarrow \mathbb{R}^3$ es de clase $C^1(D)$ tal que $D \subset H \cup S$ entonces :

# %% [markdown]
# $$\iint_{S}\bar{f}\cdot \bar{n} \cdot \bar{dr}  = \iiint_{H} div\bar{f} dv$$

# %% [markdown]
# #### Ej:

# %% [markdown]
# Sea $\bar{f}(x,y,z) = (xy,y^2+e^{xz^2},\sin (xy))$ y $H = \begin{Bmatrix}(x,y,z) \in \mathbb{R}^3: 0\leq z \leq 1-x^2 ,0 \leq y \leq 2-z\end{Bmatrix}$ calcular: $$\iint_{S}\bar{f}\cdot \bar{n} \cdot \bar{dr} $$

# %% [markdown]
# Notemos que $\bar{f} \in C^2 $

# %% [markdown]
# Empezamos calculando la divergencia de $\bar{f}$:

# %% [markdown]
# $div\bar{f} = y +2y = 3y$

# %% [markdown]
# $\hspace{1pt}$

# %% [markdown]
# Hallamos el limite de $x$:

# %% [markdown]
# Graficamos $z \leq 1-x^2$

# %% [markdown]
# ![Teoremas%20de%20Integrales.JPG](attachment:Teoremas%20de%20Integrales.JPG)

# %% [markdown]
# La integral queda:

# %% [markdown]
# $$\iint_{S}\bar{f}\cdot \bar{n} \cdot \bar{dr} = \iiint_{H} 3y dv$$

# %% [markdown]
# $$\int_{-1}^{1}dx\int_{0}^{1-x^2}dz\int_{0}^{2-z}3ydy = \frac{184}{35}$$

# %% [markdown]
# Dejamos la resolución de la integral a cargo del lector.

# %% [markdown]
# ## Teorema de Green

# %% [markdown]
# Sea un campo vectorial $\bar{f}(x,y) = \left ( P(x,y),Q(x,y) \right )$ con $\bar{f} : D_{\bar{f}} \subset \mathbb{R}^2 \rightarrow \mathbb{R}^2 \;\;,\;\; \bar{f}\in C^1\;\;,\;\; D_{\bar{f}} \subset R \cup C$ siendo $C$ la curva cerrada, simple y suave frontera de R. Entonces:

# %% [markdown]
# $$\oint_{C}\bar{f}\cdot \bar{ds} = \iint_{R}\left(\frac{\partial Q}{\partial x}-\frac{\partial P}{\partial y}\right) dxdy$$

# %% [markdown]
# #### Ej:

# %% [markdown]
# Sea $R =  \left \{ (x,y) \in \mathbb{R}^2: \left | y \right | \leq x \;\;,\;\; x^2+y^2 \leq 2x  \right \}$ y $\bar{f}(x,y) =  \left ( xe^{\sin x} -y , x+y \ln^4[y^2+1] \right )$

# %% [markdown]
# Calcular la circulación de $\bar{f}$ a lo largo de $C$ donde $C$ es la curva frontera de $R$

# %% [markdown]
# Operamos la segunda ecuación de $R$ y graficamos:

# %% [markdown]
# $$\begin{matrix}
# x^2+y^2 \leq 2x\\
# x^2-2x+y^2 \leq 0\\
# x^2-2x+1+y^2 \leq 1\\
# (x-1)^2 + y^2 \leq 1
# \end{matrix}$$

# %% [markdown]
# $\hspace{1pt}$

# %% [markdown]
# $\hspace{1pt}$

# %% [markdown]
# ![Teoremas%20de%20Integrales2.JPG](attachment:Teoremas%20de%20Integrales2.JPG)

# %% [markdown]
# Sabemos que $C=C_1 \cup C_2 \cup C_3$

# %% [markdown]
# Sin aplicar el teorema de Green la integral queda así:

# %% [markdown]
# $$\oint_{C}\bar{f}\cdot \bar{ds} = \int_{C_1}\bar{f}\cdot \bar{ds} +\int_{C_2}\bar{f}\cdot \bar{ds} + \int_{C_3}\bar{f}\cdot \bar{ds}$$

# %% [markdown]
# Y deberíamos parametrizar cada una de las curvas, pero si aplicamos el teorema de Green podemos simplificar el ejercicio:

# %% [markdown]
# Sabemos que $\bar{f} \in C^1$ por ser suma, producto y composición de funciones $C^1$ entonces podemos reescribir la integral:

# %% [markdown]
# $$\oint_{C}\bar{f}\cdot \bar{ds} = \iint_{R}\left( \frac{\partial Q}{\partial x}-\frac{\partial P}{\partial y}\right) dx dy = \iint_{R} 2\cdot dxdy$$

# %% [markdown]
# Luego: $$2\iint_{R}dxdy = 2\left [ \frac{2\cdot1}{2} +\frac{\pi}{2} \right ] = 2+ \pi$$

# %% [markdown]
# Sabemos que $\iint_{R}dxdy$ representa el area de la región $R$ y esta está compuesta por un triangulo y medio circulo. $a(t)= \frac{b\cdot h}{2}$ y
# $a(c)= \frac{\pi \cdot r^2}{2}$ mirando el grafico podemos identificar facilmente todos los parametros necesarios para calcular las areas.

# %% [markdown]
# ### Generalización del teorema de Green

# %% [markdown]
# Si $Q_x-P_y = k$ entonces: $$\oint_{C}\bar{f}\cdot \bar{ds} = k \iint_{R}dxdy$$ donde la segundra integral representa el area de $R$

# %% [markdown]
# Dada una curva $C$ cerrada simple en $\mathbb{R}^2$ y además un conjunto de curvas $c_i$ donde $c_i \cap c_j = \emptyset$ con $i\neq j$

# %% [markdown]
# ![Teoremas%20de%20Integrales3.JPG](attachment:Teoremas%20de%20Integrales3.JPG)

# %% [markdown]
# Entonces: $$\oint_{C}\bar{f}\cdot \bar{ds} -\sum_{i=1}^{k}\oint_{C_i}\bar{f}\cdot \bar{ds} = \iint_{R}\left( \frac{\partial Q}{\partial x}-\frac{\partial P}{\partial y}\right) dx dy$$

# %% [markdown]
# Es decir, el area encerrada por la curva $C$ menos la sumatoria de las areas encerradas por las curvas $c_i$ es igual a la región $R$.

# %% [markdown]
# #### Ej:

# %% [markdown]
# Dado $\bar{f} : \mathbb{R}^2 -\{\bar{A}\} \rightarrow \mathbb{R}^2 \;/\; \bar{f} = (P,Q)$ suponga matriz jacobiana continua con $Q'_x - P'_y = 6$
#
# Calcule $\oint_{C_1}\bar{f}\cdot \bar{ds}$ sabiendo que $\oint_{C_2}\bar{f}\cdot \bar{ds} = 12$ , $C_1$ es una circunferencia de radio $8$ , $C_2$ es un cuadrado de lado $5$.

# %% [markdown]
# Primero graficamos:

# %% [markdown]
# ![Teoremas%20de%20Integrales4.JPG](attachment:Teoremas%20de%20Integrales4.JPG)

# %% [markdown]
# La matriz jacobiana continua significa que $\bar{f} \in C^1 (\mathbb{R}^2-\{\bar{A}\})$

# %% [markdown]
# Por la generalización del teorema de Green sabemos que:

# %% [markdown]
# $$\oint_{C_1}\bar{f}\cdot \bar{ds} -\oint_{C_2}\bar{f}\cdot \bar{ds} = \iint_{R}( Q_x - P_y) dx dy$$

# %% [markdown]
# $$\oint_{C_1}\bar{f}\cdot \bar{ds} - 12 = 6\iint_{R} dx dy$$

# %% [markdown]
# $$\oint_{C_1}\bar{f}\cdot \bar{ds}  = 6a(R) + 12$$

# %% [markdown]
# $$a(R) = area(circulo) - area(cuadrado)$$

# %% [markdown]
# $$a(r)= 64\pi - 25$$

# %% [markdown]
# $$\oint_{C_1}\bar{f}\cdot \bar{ds}  = 64\pi - 25 + 12$$

# %% [markdown]
# $$\oint_{C_1}\bar{f}\cdot \bar{ds}  = 384\pi - 138$$

# %% [markdown]
# ## Teorema del rotor o de stokes

# %% [markdown]
# Sea $S$ una superficie abierta, simple y orientada con curva de borde $C$ y suave orientada según $S$ y sea $\bar{f} : D \subset \mathbb{R}^3 \rightarrow \mathbb{R}^3 \;\;/\;\; f \in C^1 (D) \,\,,\,\, D\subset S \cup C$ entonces:

# %% [markdown]
# $$\oint_{C}\bar{f} \cdot \bar{ds} = \iint_{S} rot\bar{f} \cdot \bar{n}\; dr$$
