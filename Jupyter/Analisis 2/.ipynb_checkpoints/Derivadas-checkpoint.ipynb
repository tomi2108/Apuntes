# %% [markdown]
# # Derivadas

# %% [markdown]
# ## Superficies parametrizadas

# %% [markdown]
# Sea $\bar{\sigma}: D_{uv} \subset \mathbb{R}^2 \rightarrow \mathbb{R}^3 / \bar{\sigma} (u,v) = \left (x(u,v),y(u,v),z(u,v)  \right )$ con $D_{uv}$ conexo y $\bar{\sigma}$ continua entonces: $$Im(\bar{\sigma}) = S$$

# %% [markdown]
# ![Derivadas1.JPG](attachment:Derivadas1.JPG)

# %% [markdown]
# ### Ej:

# %% [markdown]
# Sea $\bar{\sigma}: D_{uv} \subset \mathbb{R}^2 \rightarrow \mathbb{R}^3 / \bar{\sigma} (u,v) = \left (u \cos v,u \sin v ,u  \right )$ y
#
# $D_{uv} = \{(u,v) \in \mathbb{R}^2: 0 \leq u \leq 2, 0 \leq v \leq 2\pi\}$

# %% [markdown]
# Escribimos la parametrización con ecuaciones cartesianas $$\left\{\begin{matrix}
# x=u \cos v \hspace{15pt} (1)\\
# y= u \sin v\hspace{15pt} (2)\\
# z = u \hspace{15pt} (3)
# \end{matrix}\right.$$

# %% [markdown]
# $$\begin{matrix}
# \text{De}(1)\hspace{10pt} x^2=u^2\cos^2 v \\
# \text{De}(2)\hspace{10pt} y^2=u^2\sin^2 v\\
# x^2+y^2=u^2\hspace{10pt}\text{como}\hspace{10pt} u\geq 0 \\
# u = \sqrt{x^2+y^2}\\
# z = \sqrt{x^2+y^2}, z\leq 2
# \end{matrix}$$

# %% [markdown]
# ![Derivadas2-2.JPG](attachment:Derivadas2-2.JPG)

# %% [markdown]
# ## Derivabilidad

# %% [markdown]
# ## Derivada de una función vectorial

# %% [markdown]
# Sea $\bar{f} : D\subset \mathbb{R} \rightarrow \mathbb{R}^n$, $t_0 \in D$ Si existe con norma finita $$\lim_{h\rightarrow 0} \frac{\bar{f}(t_0+h)-\bar{f}(t_0)}{h}$$ diremos que $\bar{f}$ es derivable en $t_0$

# %% [markdown]
# $$\bar{f}'(t_0)=\lim_{h\rightarrow 0} \frac{\bar{f}(t_0+h)-\bar{f}(t_0)}{h} $$

# %% [markdown]
# O bien, $$\bar{f}'(t_0)=\lim_{t\rightarrow t_0} \frac{\bar{f}(t)-\bar{f}(t_0)}{t-t_0} $$

# %% [markdown]
# Una función vectorial es derivble en un punto $t_0$ si y solo si las componentes son derivalbes en ese punto.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Si $\bar{f}(t)$ representa la posición de una particula en cada instante $t$:
#
# Vector velocidad:  $\bar{v}(t) =\bar{f}' (t)$
#
# Rapidez : $s(t)= ||\bar{f}' (t)||$
#
# Vector aceleración: $\bar{a}(t) = \bar{v}' (t) = \bar{f}'' (t)$

# %% [markdown]
# ### Ej:

# %% [markdown]
# Sea $\bar{f} : D\subset [0,4] \rightarrow \mathbb{R}^2 /\bar{f}(t) = \left(\sqrt{t},2-t\right)$

# %% [markdown]
# $C = Im(\bar{f})$

# %% [markdown]
# Primero encontremos los limites de $x$ y despues escribamos $y$ en función de $x$

# %% [markdown]
# $$\begin{matrix}
# 0\leq t \leq 4\\
# 0\leq \sqrt{t} \leq \sqrt{4} \\
# 0\leq \sqrt{t} \leq 2\\
# 0\leq  x \leq 2
# \end{matrix}$$

# %% [markdown]
# $$\left\{\begin{matrix}
# x=\sqrt{t} \rightarrow x^2 = t \\
# y = 2-t \rightarrow y = 2- x^2, 0 \leq x \leq 2
# \end{matrix}\right.$$

# %% [markdown]
# Graficamos y hallamos el vector tangente.

# %% [markdown]
# ![Derivadas5.JPG](attachment:Derivadas5.JPG)

# %% [markdown]
# ## Punto regular de una curva

# %% [markdown]
# Un puto $P_0 = \bar{f} (t_0)$ es un punto regular de $C= Im(\bar{f})$ si y solo si $\exists \bar{f}'(t_0) \;\;\wedge\;\; \bar{f}'(t_0) \neq 0$

# %% [markdown]
# En el ejemplo, $P_0 = (1,1) =\bar{f} (1) $  es un punto regular

# %% [markdown]
# ## Punto simple

# %% [markdown]
# Un punto $P_0 = \bar{f} (t_0)$ es un punto simple de la curva $C$ cuando es imágen de un solo punto del dominio.

# %% [markdown]
# ## Recta tangente y plano normal

# %% [markdown]
# ### Recta tangente

# %% [markdown]
# $\bar{x} = P_0 + \lambda \cdot \bar{f}'(t_0) , \;\; \lambda \in \mathbb{R}$

# %% [markdown]
# ### Plano normal

# %% [markdown]
# $\bar{f}' (t_0) \cdot (\bar{x} - P_0) = 0$

# %% [markdown]
# ![Derivadas6.JPG](attachment:Derivadas6.JPG)

# %% [markdown]
# ## Derivadas de campos esclares

# %% [markdown]
# Sea $f : D \subset \mathbb{R} ^2 \rightarrow \mathbb{R} / z= f(x,y)$ y $P_0= (x_0,y_0) \in D$

# %% [markdown]
# Derivada parcial de $f$ en el punto $P_0$ se denota por:
# $f_x (P_0),$
#
# $f_x' (P_0), $
#
# $\frac{\partial f}{\partial x}(P_0), $
#
# $D_1 f(P_0)$

# %% [markdown]
# Si el limite existe entonces:

# %% [markdown]
# $$f_x (P_0) = \lim_{h\rightarrow 0} \frac{f(x_0+h,y_0)-f(x_0,y_0)}{h}$$

# %% [markdown]
# Analogamente:

# %% [markdown]
# $$f_y (P_0) = \lim_{h\rightarrow 0} \frac{f(x_0,y_0+h)-f(x_0,y_0)}{h}$$

# %% [markdown]
# ### Interpretación geometrica de las derivadas parciales

# %% [markdown]
# ![Derivadas7.JPG](attachment:Derivadas7.JPG)

# %% [markdown]
# ## Derivada direccional de un campo escalar

# %% [markdown]
# Sea $f : D \subset \mathbb{R} ^n \rightarrow \mathbb{R} / z= f(x,y)$ , $P_0 \in  D $ y $ \bar{v}  \in  \mathbb{R}^n$
#
# Si el limite existe la derivada en dirección de $\bar{v}$ se define:

# %% [markdown]
# $$f'(P_0,\bar{v}) =\lim_{h\rightarrow 0} \frac{f(P_0+h\bar{v})-f(P_0)}{h} $$

# %% [markdown]
# Caso particular $\bar{v}= \bar{0}$, la derivada en dirección del vector nulo siempre existe y vale $0$.

# %% [markdown]
# ![Derivadas8.JPG](attachment:Derivadas8.JPG)

# %% [markdown]
# $\bar{x} = P_0 + h\cdot \bar{v} ,  h \in \mathbb{R}$ son puntos de una recta.

# %% [markdown]
# Cuando $||\bar{v}|| = 1$ la derivada recibe el nombre de **derivada direccional**
#
# En este caso las derivadas parciales son un caso particular cuando se deriva en la dirección de los versores canónicos.

# %% [markdown]
# ## Propiedad de homogeneidad

# %% [markdown]
# $$f'(P_0,k\bar{v}) = k f'(P_0, \bar{v})$$

# %% [markdown]
# ### Utilidad

# %% [markdown]
# $$f'(P_0,\breve{v}) =  \frac{1}{||\bar{v}||}\cdot f'(P_0, \bar{v})$$

# %% [markdown]
# ## Derivada direccional de un campo vectorial

# %% [markdown]
# Sea $\bar{f} : D \subset \mathbb{R}^n \rightarrow \mathbb{R}^m $, $P_0\in D $, $\breve{v} \in \mathbb{R}^m$ $/ ||\breve{v}|| = 1$

# %% [markdown]
# $$\bar{f}'(P_0,\bar{v}) =\lim_{h\rightarrow 0} \frac{\bar{f}(P_0+h\bar{v})-\bar{f}(P_0)}{h} $$

# %% [markdown]
# Este limite existe si y solo si  existen los limites de todas las componentes.

# %% [markdown]
# ## Derivadas parciales sucesivas

# %% [markdown]
# ![Derivadas9.JPG](attachment:Derivadas9.JPG)

# %% [markdown]
# ## Teorema de Schwarz

# %% [markdown]
# Sea $f:D_f \subset \mathbb{R}^2 \rightarrow \mathbb{R}$ y el punto $P_0=(x_0,y_0)$ interior a $D_f$ ,si existen $f_x, f_y$ y $f_{xy}$ en un entorno de $P_0$ y $f_{xy}$ es continua en $P_0$ , entonces existe y $f_{yx}(P_0)$resultando $f_{yx}(P_0)=f_{xy}(P_0)$

# %% [markdown]
# # Diferenciabilidad

# %% [markdown]
# Sea $f:D\subset \mathbb{R}^2\rightarrow \mathbb{R}\;\;/\;\;z=f(x,y)$ y $P_0=(x_0,y_0)\in D$

# %% [markdown]
# $f$ es diferenciable en $P_0$ si $f_x(P_0)$ y $f_y(P_0)$ existen y:
#
#
# $$\lim_{(x,y)\rightarrow (x_0,y_0)}\frac{f(x,y)-[f(x_0,y_0)+f_x(x_0,y_0)(x-x_0)+f_y(x_0,y_0)(y-y_0)]}{||(x,y)- (x_0,y_0)||} = 0$$

# %% [markdown]
# ### Plano tangente

# %% [markdown]
# $$ z= f(x_0,y_0)+f_x(x_0,y_0)(x-x_0)+f_y(x_0,y_0)(y-y_0)$$

# %% [markdown]
# ## Gradiente

# %% [markdown]
# Sea $f:D\subset \mathbb{R}^n\rightarrow \mathbb{R}$, $P_0=(x_0,y_0)$

# %% [markdown]
# El vector cuyas componentes son las $n$ derivadas parciales de $f$ en $P_0$ se llama gradiente de la función en $P_0$ y se denota: $$\bar{\nabla}f(P_0)=\left ( \frac{\partial f}{\partial x},\frac{\partial f}{\partial x_2},\cdots,\frac{\partial f }{\partial x_n} \right )=grad(f)$$

# %% [markdown]
# Para que exista el vector gradiente en un punto deben existir las $n$ derivadas parciales en ese punto.

# %% [markdown]
# ### Caso general

# %% [markdown]
# Sea $f:D\subset \mathbb{R}^n\rightarrow \mathbb{R}\;\;/\;\;z=f(x,y)$ y $P_0=(x_0,y_0)\in D$ tal que existen las $n$ derivadas parciales en $P_0$ entonces $f$ es diferenciable en $P_0$ si:
#
# $$\lim_{\bar{x}\rightarrow P_0}\frac{f(\bar{x})-f(P_0)-\nabla f(P_0) \cdot(\bar{x}-P_0)}{||\bar{x}- P_0||} = 0$$

# %% [markdown]
# Si $f$ es diferenciable en $P_0$ entonces $f$ es continua en $P_0$.
#
# Si $f$ no es continua en $P_0$ entonces $f$ no es diferenciable en $P_0$

# %% [markdown]
# Si $f$ es diferenciable en $P_0$ entonces existe $f'(P_0,\bar{v}) \;\;\forall \bar{v}$ y:
#
# $$f'(P_0,\bar{v}) = \bar{\nabla} f (P_0) \cdot \bar{v}$$

# %% [markdown]
# Las funciones polinomicas son diferenciables en $\mathbb{R}^n$

# %% [markdown]
# ## Propiedades de la matriz jacobiana

# %% [markdown]
# Si $\bar{f}: D\subset \mathbb{R}^n \rightarrow \mathbb{R}^n$ y $P_0 \in D$ es tal que existen todas las derivadas parciales de $\bar{f}$ en $P_0$ y son continuas en un $E(P_0)$ entonces $D\bar{f}(P_0)$ es continua y $\bar{f}$ es diferenciable en $P_0$

# %% [markdown]
# ## Componentes de un vector normal al plano tangente

# %% [markdown]
# $$\bar{N}=\left (f_x(x_0,y_0),f_y(x_0,y_0),-1  \right )$$

# %% [markdown]
# ![Derivadas10.JPG](attachment:Derivadas10.JPG)

# %% [markdown]
# ## Ecuación del plano tangente

# %% [markdown]
# ![Derivadas11.JPG](attachment:Derivadas11.JPG)

# %% [markdown]
# ## Ecuación vectorial de la recta normal

# %% [markdown]
# En el punto $(x_0,y_0,f(x,y))$

# %% [markdown]
# ![Derivadas12.JPG](attachment:Derivadas12.JPG)

# %% [markdown]
# ## Derivada direccional maxima, minima y nula

# %% [markdown]
# ![Derivadas13.JPG](attachment:Derivadas13.JPG)

# %% [markdown]
# ![Derivadas14.JPG](attachment:Derivadas14.JPG)

# %% [markdown]
# ![Derivadas15.JPG](attachment:Derivadas15.JPG)

# %% [markdown]
# ## Formula de aproximacion lineal de campos escalares

# %% [markdown]
# ![Derivadas16.JPG](attachment:Derivadas16.JPG)

# %% [markdown]
# ## En superficies parametrizadas

# %% [markdown]
# ![Derivadas17.JPG](attachment:Derivadas17.JPG)

# %% [markdown]
# ## Teorema de composición de funciones

# %% [markdown]
# ![Derivadas18.JPG](attachment:Derivadas18.JPG)

# %% [markdown]
# ## Caso particular

# %% [markdown]
# ![Derivadas19.JPG](attachment:Derivadas19.JPG)

# %% [markdown]
# ![Derivadas20.JPG](attachment:Derivadas20.JPG)

# %% [markdown]
# ## Apliación de la regla de la cadena

# %% [markdown]
# ![Derivadas21.JPG](attachment:Derivadas21.JPG)

# %% [markdown]
# ![Derivadas22.JPG](attachment:Derivadas22.JPG)

# %% [markdown]
# ![Derivadas23.JPG](attachment:Derivadas23.JPG)

# %% [markdown]
# ![Derivadas24.JPG](attachment:Derivadas24.JPG)
